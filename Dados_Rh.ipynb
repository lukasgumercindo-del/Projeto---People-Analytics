# %%
import pandas as pd 
import numpy as np

np.random.seed(42)

n_funcionarios = 1000

ids= [f"EMP{i:04d}" for i in range (1, n_funcionarios +1 )]
idades = np.random.randint(22, 56, size=n_funcionarios)
generos = np.random.choice(["Masculino", "Feminino", "Não-binário"], size=n_funcionarios, p=[0.48, 0.49, 0.03])

depts_lista = ["Vendas", "Tecnologia", "Recursos Humanos", "Marketing", "Operações"]
departamentos = np.random.choice(depts_lista, size=n_funcionarios, p=[0.30, 0.25, 0.08, 0.12, 0.25])

niveis = np.random.choice(["Junior", "Pleno", "Senior"], size=n_funcionarios, p=[0.50, 0.35, 0.15])

salarios = []
for nivel in niveis: 
    if nivel == "Junior":
        salarios.append(round(np.random.uniform(3500, 5000),2))
    elif nivel == "Pleno":
        salarios.append(round(np.random.uniform(5500, 8500),2))
    else: 
        salarios.append(round(np.random.uniform(9000, 15000),2))
        
tempo_empresa_meses = np.random.randint(1, 72, size=n_funcionarios)
satisfacao = np.random.randint(1, 6, size=n_funcionarios)
performance = np.random.randint(1, 6, size=n_funcionarios)

status = []
for i in range(n_funcionarios):
    if satisfacao[i] <= 2:
        status.append(np.random.choice(["Ativo", "Inativo"], p=[0.40, 0.60]))
    else:
        status.append(np.random.choice(["Ativo", "Inativo"], p=[0.90, 0.10]))

df_rh = pd.DataFrame({
    "id_funcionario": ids,
    "idade": idades,
    "genero": generos,
    "departamento": departamentos,
    "nivel": niveis,
    "salario": salarios,
    "tempo_casa_meses": tempo_empresa_meses,
    "nota_satisfacao": satisfacao,
    "nota_performance": performance,
    "status": status
})

df_rh.to_csv("dados_brutos_rh.csv", index=False)
print("Base de dados de People Analytics gerada com sucesso! O arquivo 'dados_brutos_rh.csv' foi criado.")

df_rh.head()
# Out:
# Base de dados de People Analytics gerada com sucesso! O arquivo 'dados_brutos_rh.csv' foi criado.
#   id_funcionario  idade     genero departamento   nivel  salario  \
# 0        EMP0001     50  Masculino    Marketing  Junior  3575.93
# 1        EMP0002     36   Feminino    Operações   Pleno  5618.18
# 2        EMP0003     29  Masculino       Vendas  Junior  4360.92
# 3        EMP0004     42   Feminino   Tecnologia  Junior  4089.34
# 4        EMP0005     40  Masculino    Operações  Junior  3542.98
#
#    tempo_casa_meses  nota_satisfacao  nota_performance   status
# 0                71                3                 5    Ativo
# 1                43                3                 4    Ativo
# 2                26                3                 5    Ativo
# 3                71                2                 5  Inativo
# 4                33                3                 4    Ativo

# %%
# %pip install psycopg2 sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    --------------- ------------------------ 1.0/2.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.8 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.8 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 2.2 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
from sqlalchemy import create_engine

df_rh = pd.read_csv("dados_brutos_rh.csv")

usuario = "postgres"
senha = "postgre123"
banco = "people_analytics_db"

engine = create_engine(f"postgresql+psycopg2://{usuario}:{senha}@localhost:5432/{banco}")

df_rh = pd.read_csv("dados_brutos_rh.csv", encoding="latin1")
df_rh = pd.read_csv("dados_brutos_rh.csv", encoding="utf-8")

usuario = "postgres"
senha = "postgre123"
banco = "people_analytics_db"

engine = create_engine(f"postgresql+psycopg2://{usuario}:{senha}@localhost:5432/{banco}")

df_rh.to_sql("funcionarios_rh", con=engine, if_exists="append", index=False)
print("Pipline Concluído! 1.000 registros de funcionários enviados ao PostgreSQL.")
print("Pipline Concluído! 1.000 registros de funcionários enviados ao PostgreSQL.")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 13
#       9
#      10 engine = create_engine(f"postgresql+psycopg2://{usuario}:{senha}@localhost:5432/{banco}")
#      11
#      12 df_rh = pd.read_csv("dados_brutos_rh.csv", encoding="latin1")
# ---> 13 df_rh.to_sql("funcionarios_rh", con=engine, if_exists="append", index=False)
#      14 print("Pipline Concluído! 1.000 registros de funcionários enviados ao PostgreSQL.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3048         3
#    3049         """  # noqa: E501
#    3050         from pandas.io import sql
#    3051
# -> 3052         return sql.to_sql(
#    3053             self,
# ...
